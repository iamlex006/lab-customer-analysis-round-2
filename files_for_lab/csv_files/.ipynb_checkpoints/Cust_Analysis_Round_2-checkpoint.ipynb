# %%
import pandas as pd

data = pd.read_csv("marketing_customer_analysis.csv")
data.shape
# Out:
# (10910, 26)

# %%
data.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
#standardize header names: remove column Unnamed 0 and add space to Employment Status header.

# %%
data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
data = data.rename(columns={'EmploymentStatus':'Employment Status'})
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date Employment Status Gender  Income  ...  \
# 0           2/18/11          Employed      M   48029  ...
# 1           1/18/11        Unemployed      F       0  ...
# 2           2/10/11          Employed      M   22139  ...
# 3           1/11/11          Employed      M   49078  ...
# 4           1/17/11     Medical Leave      F   23675  ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
data.dtypes
data._get_numeric_data()
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
data.dtypes
data.select_dtypes(['object'])
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       Employment Status Gender Location Code Marital Status     Policy Type  \
# ...

# %%
data.isna().sum()
round(data.isna().sum()/len(data),4)*100
nulls_df = pd.DataFrame(round(data.isna().sum()/len(data),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                        Customer           0.00
# 1                           State           5.78
# 2         Customer Lifetime Value           0.00
# 3                        Response           5.78
# 4                        Coverage           0.00
# 5                       Education           0.00
# 6               Effective To Date           0.00
# 7               Employment Status           0.00
# 8                          Gender           0.00
# 9                          Income           0.00
# 10                  Location Code           0.00
# 11                 Marital Status           0.00
# 12           Monthly Premium Auto           0.00
# 13        Months Since Last Claim           5.80
# 14  Months Since Policy Inception           0.00
# 15      Number of Open Complaints           5.80
# 16             Number of Policies           0.00
# 17                    Policy Type           0.00
# ...

# %%
data["State"].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: State, dtype: int64

# %%
data["State"] = data["State"].fillna("Unknown") #Too many NaN to use "most common value"so creating Ünknown"state. 

data["State"].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Unknown        631
# Name: State, dtype: int64

# %%
data["Response"].value_counts(dropna=False)
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: Response, dtype: int64

# %%
data["Response"] = data["Response"].fillna("Unknown") #5% NaN attributed to most common would skew the results so also creating Ünknown"

data["Response"].value_counts(dropna=False)
# Out:
# No         8813
# Yes        1466
# Unknown     631
# Name: Response, dtype: int64

# %%
#For both Months Since Last Claim and Open Complaints, since these are quantifiable I'll replace the NaN with the mean of the data set.

# %%
data["Months Since Last Claim"].value_counts(dropna=False)
# Out:
# NaN     633
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 19.0    276
# 23.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: Months Since Last Claim, dtype: int64

# %%
import numpy as np
mean_claim = data['Months Since Last Claim'].mean()
mean_claim
data['Months Since Last Claim'] = data['Months Since Last Claim'].fillna(mean_claim)

# %%
data["Months Since Last Claim"].value_counts(dropna=False) #just checking
# Out:
# 15.149071    633
# 3.000000     426
# 6.000000     394
# 1.000000     386
# 7.000000     378
# 4.000000     373
# 2.000000     368
# 5.000000     355
# 0.000000     354
# 10.000000    346
# 16.000000    333
# 11.000000    331
# 15.000000    323
# 13.000000    320
# 8.000000     315
# 12.000000    307
# 17.000000    299
# 14.000000    299
# 9.000000     277
# 19.000000    276
# 23.000000    276
# 25.000000    269
# 21.000000    267
# 18.000000    257
# 20.000000    254
# 22.000000    246
# 24.000000    237
# 29.000000    234
# 28.000000    227
# 31.000000    221
# 26.000000    211
# 27.000000    208
# 30.000000    201
# 34.000000    199
# 33.000000    198
# 35.000000    157
# 32.000000    155
# Name: Months Since Last Claim, dtype: int64

# %%
data["Number of Open Complaints"].value_counts(dropna=False)
# Out:
# 0.0    8160
# 1.0    1145
# NaN     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: Number of Open Complaints, dtype: int64

# %%
mean_complaints = data['Number of Open Complaints'].mean()
mean_complaints
data['Number of Open Complaints'] = data['Number of Open Complaints'].fillna(mean_complaints)

# %%
data["Number of Open Complaints"].value_counts(dropna=False)
# Out:
# 0.000000    8160
# 1.000000    1145
# 0.384256     633
# 2.000000     414
# 3.000000     324
# 4.000000     166
# 5.000000      68
# Name: Number of Open Complaints, dtype: int64

# %%
data["Vehicle Class"].value_counts(dropna=False)
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: Vehicle Class, dtype: int64

# %%
data["Vehicle Class"] = data["Vehicle Class"].fillna("Four-Door Car") #4 door car has 50% of set, so makes sense to add NaN to that cateogry.
data["Vehicle Class"].value_counts(dropna=False)
# Out:
# Four-Door Car    5834
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: Vehicle Class, dtype: int64

# %%
data["Vehicle Size"].value_counts(dropna=False)
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: Vehicle Size, dtype: int64

# %%
data["Vehicle Size"] = data["Vehicle Size"].fillna("Medsize") #4 door car has 50% of set, so makes sense to add NaN to that cateogry.
data["Vehicle Size"].value_counts(dropna=False)
# Out:
# Medsize    7873
# Small      1966
# Large      1071
# Name: Vehicle Size, dtype: int64

# %%
data["Vehicle Type"].value_counts(dropna=False)
# Out:
# NaN    5482
# A      5428
# Name: Vehicle Type, dtype: int64

# %%
data["Vehicle Type"] = data["Vehicle Type"].fillna("Unknown") #I'd be tempted to drop the column as doesn't seem useful, but keeping it in case find use later.
data["Vehicle Type"].value_counts(dropna=False)
# Out:
# Unknown    5482
# A          5428
# Name: Vehicle Type, dtype: int64

# %%
#remove dupilcates

# %%
print(data.shape)
data2 = data.copy()
data2 = data2.drop_duplicates()
print(data2.shape)
# Out:
# (10910, 25)
# (10792, 25)

# %%
#exctract the months and store in separate column.

# %%
data2.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# Employment Status                 object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
data2['Effective To Date'] = pd.to_datetime(data2['Effective To Date'], errors='coerce')
data2.dtypes
# Out:
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# Employment Status                        object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                 float64
# Months Since Policy Inception             int64
# Number of Open Complaints               float64
# Number of Policies                        int64
# Policy Type                              object
# Policy                                   object
# Renew Offer Type                         object
# ...

# %%
data2["Effective_month"] = data2['Effective To Date'][0].month
data2.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date Employment Status Gender  Income  ... Number of Policies  \
# 0        2011-02-18          Employed      M   48029  ...                  9
# 1        2011-01-18        Unemployed      F       0  ...                  1
# 2        2011-02-10          Employed      M   22139  ...                  2
# 3        2011-01-11          Employed      M   49078  ...                  2
# 4        2011-01-17     Medical Leave      F   23675  ...                  7
#
# ...

# %%
data2[data2["Effective_month"]<4]
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
#       Education Effective To Date Employment Status Gender  Income  ...  \
# ...

# %% [markdown]
# # Start of Round 3

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10792 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       10792 non-null  object
#  1   State                          10792 non-null  object
#  2   Customer Lifetime Value        10792 non-null  float64
#  3   Response                       10792 non-null  object
#  4   Coverage                       10792 non-null  object
#  5   Education                      10792 non-null  object
#  6   Effective To Date              10792 non-null  datetime64[ns]
#  7   Employment Status              10792 non-null  object
#  8   Gender                         10792 non-null  object
#  9   Income                         10792 non-null  int64
#  10  Location Code                  10792 non-null  object
#  11  Marital Status                 10792 non-null  object
# ...

# %%
data2.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             10792.000000  10792.000000          10792.000000
# mean               8014.130631  37562.678188             93.325241
# std                6876.857777  30369.777286             34.533652
# min                1898.007675      0.000000             61.000000
# 25%                4014.453113      0.000000             68.000000
# 50%                5780.182197  33808.500000             83.000000
# 75%                8996.840617  62277.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count             10792.000000                   10792.000000
# mean                 15.143850                      48.123981
# std                   9.783319                      27.920585
# min                   0.000000                       0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(data2['Response'], bins=3)
plt.show()

# %%
table_channel = data.groupby(["Sales Channel", "Response"]).size()
display(table_channel)
# Out:
# Sales Channel  Response
# Agent          No          3148
#                Unknown      231
#                Yes          742
# Branch         No          2539
#                Unknown      157
#                Yes          326
# Call Center    No          1792
#                Unknown      128
#                Yes          221
# Web            No          1334
#                Unknown      115
#                Yes          177
# dtype: int64

# %%
rates = []
for i in range(1, len(table_channel), 3):
    rates.append(table_channel[i]/(table_channel[i]+table_channel[i-1]+table_channel[i-2])*100)
rates
# Out:
# [6.496062992125983, 4.566608493310064, 5.699020480854853, 6.88622754491018]

# %%
#the figures are now percentages, as they should be, but I don't know how to add the % sign to the data while keeping it a numerical...

# %%
sns.barplot(x=data2['Sales Channel'].unique(), y=rates)
plt.show()

# %%
#Response rate by total claim amount. First create categories for the total claim amount, then use same method as above.

# %%
def claim_cat(x):
    if x <500:
        return "A 0-499"
    elif x<1000:
        return "B 500-999"
    elif x<1500:
        return "C 1000-1499"
    elif x<2000:
        return "D 1500-1999"
    elif x<2500:
        return "E 2000-2499"
    else:
        return "F 2500-2999"
    
data2['Claim Interval'] = list(map(claim_cat, data2['Total Claim Amount']))
data2['Claim Interval'].unique()  # To check the results again
data2
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
#       Education Effective To Date Employment Status Gender  Income  ...  \
# ...

# %%
table_claim = data2.groupby(["Claim Interval", "Response"]).size()
display(table_claim)
# Out:
# Claim Interval  Response
# A 0-499         No          5941
#                 Unknown      429
#                 Yes          937
# B 500-999       No          2388
#                 Unknown      158
#                 Yes          450
# C 1000-1499     No           319
#                 Unknown       20
#                 Yes           67
# D 1500-1999     No            58
#                 Unknown        3
# E 2000-2499     No            16
#                 Unknown        2
# F 2500-2999     No             4
# dtype: int64

# %%
rates_claim = []
for i in range(1, len(table_claim), 3):
    rates_claim.append(table_claim[i]/(table_claim[i]+table_claim[i-1]+table_claim[i-2])*100)
rates_claim
# Out:
# [6.7304675243175405,
#  4.536319265001436,
#  2.5348542458808616,
#  2.34375,
#  18.181818181818183]

# %%
#The plot isn't working because there isn't a "yes" in all categories!!! How to stop the for (make it a while???)

# %%
#sns.barplot(x=data2['Claim Interval'].unique(), y=rates_claim)
#plt.show()

# %%
#response rate by Income

# %%
table_income = data.groupby(["Income", "Response"]).size()
display(table_income)
# Out:
# Income  Response
# 0       No          2392
#         Unknown      169
#         Yes          226
# 10037   No             1
# 10074   No             1
#                     ...
# 99875   No             1
# 99934   No             1
# 99960   No             1
# 99961   No             1
# 99981   No             1
# Length: 6128, dtype: int64

# %%
def income_cat(x):
    if x <20000:
        return "A 0 - 19999"
    elif x<40000:
        return "B 20000 - 39999"
    elif x<60000:
        return "C 40000 - 59999"
    elif x<80000:
        return "D 60000 - 79999"
    else:
        return "E 80000 - 99999"
    
data2['Income Interval'] = list(map(income_cat, data2['Income']))
data2['Income Interval'].unique()  # To check the results again
data2
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
#       Education Effective To Date Employment Status Gender  Income  ...  \
# ...

# %%
table_income = data2.groupby(["Income Interval", "Response"]).size()
display(table_income)
# Out:
# Income Interval  Response
# A 0 - 19999      No          2779
#                  Unknown      195
#                  Yes          403
# B 20000 - 39999  No          2079
#                  Unknown      145
#                  Yes          453
# C 40000 - 59999  No          1487
#                  Unknown       93
#                  Yes          216
# D 60000 - 79999  No          1374
#                  Unknown      115
#                  Yes          257
# E 80000 - 99999  No          1007
#                  Unknown       64
#                  Yes          125
# dtype: int64

# %%
rates_income = []
for i in range(1, len(table_income), 3):
    rates_income.append(table_income[i]/(table_income[i]+table_income[i-1]+table_income[i-2])*100)
rates_income
# Out:
# [6.292352371732816,
#  5.519604111153407,
#  4.574520413182489,
#  6.744868035190615,
#  4.819277108433735]

# %%
sns.barplot(x=data2['Income Interval'].unique(), y=rates_income)
plt.show()

# %% [markdown]
# # Start Round 4

# %%
data2.dtypes
# Out:
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# Employment Status                        object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                 float64
# Months Since Policy Inception             int64
# Number of Open Complaints               float64
# Number of Policies                        int64
# Policy Type                              object
# Policy                                   object
# Renew Offer Type                         object
# ...

# %%
numerical = data2._get_numeric_data()
numerical.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              4809.216960   48029                    61
# 1              2228.525238       0                    64
# 2             14947.917300   22139                   100
# 3             22332.439460   49078                    97
# 4              9025.067525   23675                   117
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                 7.000000                             52
# 1                 3.000000                             26
# 2                34.000000                             31
# 3                10.000000                              3
# 4                15.149071                             31
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount  \
# 0                   0.000000                   9          292.800000
# 1                   0.000000                   1          744.924331
# ...

# %%
categoricals = data2.select_dtypes(include=['object', "datetime64"])
categoricals.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  DK49336     Arizona       No     Basic   College        2011-02-18
# 1  KX64629  California       No     Basic   College        2011-01-18
# 2  LZ68649  Washington       No     Basic  Bachelor        2011-02-10
# 3  XL78013      Oregon      Yes  Extended   College        2011-01-11
# 4  QA50777      Oregon       No   Premium  Bachelor        2011-01-17
#
#   Employment Status Gender Location Code Marital Status     Policy Type  \
# 0          Employed      M      Suburban        Married  Corporate Auto
# 1        Unemployed      F      Suburban         Single   Personal Auto
# 2          Employed      M      Suburban         Single   Personal Auto
# 3          Employed      M      Suburban         Single  Corporate Auto
# 4     Medical Leave      F      Suburban        Married   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
sns.displot(numerical['Customer Lifetime Value'], bins=40)
plt.show()

# %%
sns.displot(numerical['Income'], bins=30)
plt.show()

# %%
sns.displot(numerical['Monthly Premium Auto'], bins=40)
plt.show()

# %%
sns.displot(numerical['Months Since Last Claim'], bins=35)
plt.show()

# %%
sns.displot(numerical['Months Since Policy Inception'], bins=20)
plt.show()

# %%
sns.displot(numerical['Number of Open Complaints'], bins=5)
plt.show()

# %%
sns.displot(numerical['Number of Policies'], bins=10)
plt.show()

# %%
sns.displot(numerical['Total Claim Amount'], bins=50)
plt.show()

# %%
sns.displot(numerical['Effective_month'], bins=3)
plt.show()

# %%
#later figured out the loop to make all plots at once...

# %%
col = numerical.columns
for i in col: 
    sns.displot(numerical[i], bins=10)
    plt.show()

# %%
#Histograms

# %%
col = numerical.columns
for i in col: 
    print(i)
    plt.hist(numerical[i])
    plt.show()
# Out:
# Customer Lifetime Value
# Income
# Monthly Premium Auto
# Months Since Last Claim
# Months Since Policy Inception
# Number of Open Complaints
# Number of Policies
# Total Claim Amount
# Effective_month

# %%
#Do the distributions for different numerical variables look like a normal distribution

# %%
#No, none of them are a normal distribution (bell).
# Out:
#   File "/var/folders/4x/ppplmryx5_d7mfrd5d6968kr0000gn/T/ipykernel_2105/3004853152.py", line 1
#     No, none of them are a normal distribution (bell).
#                                                        ^
# SyntaxError: invalid syntax

# %%
#Multicollinearity

# %%
correlations_matrix = numerical.corr()
correlations_matrix
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.026466
# Income                                        0.026466  1.000000
# Monthly Premium Auto                          0.404153 -0.011097
# Months Since Last Claim                       0.014163 -0.022771
# Months Since Policy Inception                 0.016347 -0.005417
# Number of Open Complaints                    -0.033659  0.006088
# Number of Policies                            0.018008 -0.009639
# Total Claim Amount                            0.233627 -0.355323
# Effective_month                                    NaN       NaN
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.404153                 0.014163
# Income                                    -0.011097                -0.022771
# Monthly Premium Auto                       1.000000                 0.008422
# ...

# %%
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
#Nothing has a high correlation so not dropping features.
